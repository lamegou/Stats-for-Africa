# %% [markdown]
# #Stats for Africa
# -----------------------------------
# Here we want to analyse the evolution of some commodities prices.
# We have gathered some time series data. The data concern the price of phosphate rock(fertilizer), gold, bananas, cocoa ,coffee arabica , crude oil from January 1960 to March

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

# %%
com=pd.read_excel('C:/Users/swordbreaker/my_notebooks/Stats-for-Africa/com_phos.xlsx','Feuil1')

# %%
com
# Out:
#                  Month     COCOA  BANANA_US  CRUDE_DUBAI  IFERTILIZERS  \
# 0    1960M01 [1960M01]  0.634000   0.143080     1.630000     12.570322
# 1    1960M02 [1960M02]  0.608000   0.143080     1.630000     12.570322
# 2    1960M03 [1960M03]  0.578900   0.143080     1.630000     12.570322
# 3    1960M04 [1960M04]  0.598300   0.143080     1.630000     12.570322
# 4    1960M05 [1960M05]  0.600100   0.149000     1.630000     12.570322
# 5    1960M06 [1960M06]  0.594400   0.149000     1.630000     12.570322
# 6    1960M07 [1960M07]  0.604500   0.149000     1.630000     12.570322
# 7    1960M08 [1960M08]  0.588200   0.126990     1.630000     12.570322
# 8    1960M09 [1960M09]  0.582700   0.138000     1.630000     12.570322
# 9    1960M10 [1960M10]  0.585800   0.154100     1.630000     12.570322
# 10   1960M11 [1960M11]  0.569500   0.127000     1.630000     12.570322
# 11   1960M12 [1960M12]  0.523800   0.149000     1.630000     12.570322
# ...

# %%
Time=pd.date_range('01/1960','02/2015',freq='M')

# %%
cocoa1
# Out:
#             PHOSROCK  COCOA  BANANA_US  COFFEE_ROBUS
# 1960-01-31       NaN    NaN        NaN           NaN
# 1960-02-29       NaN    NaN        NaN           NaN
# 1960-03-31       NaN    NaN        NaN           NaN
# 1960-04-30       NaN    NaN        NaN           NaN
# 1960-05-31       NaN    NaN        NaN           NaN
# 1960-06-30       NaN    NaN        NaN           NaN
# 1960-07-31       NaN    NaN        NaN           NaN
# 1960-08-31       NaN    NaN        NaN           NaN
# 1960-09-30       NaN    NaN        NaN           NaN
# 1960-10-31       NaN    NaN        NaN           NaN
# 1960-11-30       NaN    NaN        NaN           NaN
# 1960-12-31       NaN    NaN        NaN           NaN
# 1961-01-31       NaN    NaN        NaN           NaN
# 1961-02-28       NaN    NaN        NaN           NaN
# 1961-03-31       NaN    NaN        NaN           NaN
# 1961-04-30       NaN    NaN        NaN           NaN
# 1961-05-31       NaN    NaN        NaN           NaN
# ...

# %%
# ?pd.DataFrame

# %%
cocoa=pd.DataFrame(com,index=Time,columns=['PHOSROCK','COCOA'])

# %%
data = {'state': ['Ohio', 'Ohio', 'Ohio', 'Nevada', 'Nevada'],
'year': [2000, 2001, 2002, 2001, 2002],
'pop': [1.5, 1.7, 3.6, 2.4, 2.9]}

# %%
dat=pd.DataFrame(data)

# %%
dat
# Out:
#    pop   state  year
# 0  1.5    Ohio  2000
# 1  1.7    Ohio  2001
# 2  3.6    Ohio  2002
# 3  2.4  Nevada  2001
# 4  2.9  Nevada  2002

# %%
dates = pd.date_range('1/1/1960','1/2015',freq='M')

# %%
dates
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2000-01-31, ..., 2000-08-31]
# Length: 8, Freq: M, Timezone: None

# %%
df = pd.DataFrame(np.random.normal(8, 4), index=dates, columns=['A', 'B', 'C', 'D'])

# %%
df
# Out:
#                    A         B         C         D
# 1960-01-31  7.677054  7.677054  7.677054  7.677054
# 1960-02-29  7.677054  7.677054  7.677054  7.677054
# 1960-03-31  7.677054  7.677054  7.677054  7.677054
# 1960-04-30  7.677054  7.677054  7.677054  7.677054
# 1960-05-31  7.677054  7.677054  7.677054  7.677054
# 1960-06-30  7.677054  7.677054  7.677054  7.677054
# 1960-07-31  7.677054  7.677054  7.677054  7.677054
# 1960-08-31  7.677054  7.677054  7.677054  7.677054
# 1960-09-30  7.677054  7.677054  7.677054  7.677054
# 1960-10-31  7.677054  7.677054  7.677054  7.677054
# 1960-11-30  7.677054  7.677054  7.677054  7.677054
# 1960-12-31  7.677054  7.677054  7.677054  7.677054
# 1961-01-31  7.677054  7.677054  7.677054  7.677054
# 1961-02-28  7.677054  7.677054  7.677054  7.677054
# 1961-03-31  7.677054  7.677054  7.677054  7.677054
# 1961-04-30  7.677054  7.677054  7.677054  7.677054
# 1961-05-31  7.677054  7.677054  7.677054  7.677054
# ...
