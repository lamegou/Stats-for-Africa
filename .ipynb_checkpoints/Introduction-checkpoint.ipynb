# %% [markdown]
# #Stats for Africa
# -----------------------------------
# Here we want to analyse the evolution of some commodities prices.
# We have gathered some time series data. The data concern the price of phosphate rock(fertilizer), gold, bananas, cocoa ,coffee arabica , crude oil from January 1960 to March

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

# %%
com=pd.read_excel('C:/Users/swordbreaker/my_notebooks/Stats-for-Africa/com_phos.xlsx','Feuil2')

# %%
com
# Out:
#                   YEAR    PHOSROCK  BANANA_US     COCOA  COFFEE_ARABIC  \
# 0    1960M01 [1960M01]   13.000000   0.142868  0.589017       0.923517
# 1    1960M02 [1960M02]   13.000000   0.143080  0.634000       0.940900
# 2    1960M03 [1960M03]   13.000000   0.143080  0.608000       0.946900
# 3    1960M04 [1960M04]   13.000000   0.143080  0.578900       0.928100
# 4    1960M05 [1960M05]   13.000000   0.143080  0.598300       0.930300
# 5    1960M06 [1960M06]   13.000000   0.149000  0.600100       0.920000
# 6    1960M07 [1960M07]   13.000000   0.149000  0.594400       0.912300
# 7    1960M08 [1960M08]   13.000000   0.149000  0.604500       0.916000
# 8    1960M09 [1960M09]   13.000000   0.126990  0.588200       0.929200
# 9    1960M10 [1960M10]   13.000000   0.138000  0.582700       0.922600
# 10   1960M11 [1960M11]   13.000000   0.154100  0.585800       0.923700
# 11   1960M12 [1960M12]   13.000000   0.127000  0.569500       0.911600
# ...

# %%
com.COCOA.plot()
